# %% [markdown]
# # Ejercicio de PowerBI SemiSenior
#
# El objetivo es resolverlos aplicando tu experiencia y conocimiento de DAX para situaciones como estas:

# %% [markdown]
# 1. Con los archivos CSV anexos (Ventas, Productos, Regiones) construir el modelo de datos estableciendo las relaciones entre tablas que consideres necesarias para procesarlo.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# 2. Construir una matriz que considere los siguientes indicadores:
#
# - Ventas
# - % Participación por nivel
# - % Variación vs año previo (considerando mismos períodos)
#
# Con desglose por la jerarquía: Año / Trimestres / Mes / Producto, como se muestra en el ejemplo a continuación.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# 3. Tomando como base la tabla del paso 2, construir una segunda tabla que visualice en cada mes el TOP 10 de productos con mayor participación de venta, sin afectar los porcentajes de cada corte (jerarquía), para homologar a 10 productos por mes la visualización, como se muestra a continuación.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# 4. La tabla de regiones solo contiene las 6 regiones de ventas de México, pero se necesita contar con una que permita agrupar las ventas a nivel nacional. No se puede duplicar la data de la tabla de ventas porque duplicaría el tamaño del dataset; por lo tanto, se requiere generar el total de ventas nacionales agrupando las 6 regiones, y que permita segmentar los datos tanto a nivel nacional como por las regiones que contiene el catálogo de regiones.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# 5. A la tabla anterior aplicar un esquema de RLS con los siguientes criterios:
#
# ![image.png](attachment:image.png)
#
# Ejemplo:
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# 6. Replicar la siguiente tabla, donde de forma dinámica se pueda cambiar entre niveles, DAX y períodos de acuerdo con los combos seleccionados.
#
# ![image.png](attachment:image.png)
